# %% [markdown]
# <a href="https://colab.research.google.com/github/fibleep/adam-mickiewicz-ai/blob/main/LLaMa_Dataset_Enrichment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Enriching and formatting the dataset
#
# We will load the Adam Mickiewicz dataset to clean it, enrich it and upload it to hugging face hub

# %% [markdown]
# Load the repository with the data

# %%
# !git clone https://github.com/fibleep/adam-mickiewicz-ai.git
# Out:
# fatal: destination path 'adam-mickiewicz-ai' already exists and is not an empty directory.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in ./.venv/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import sys
sys.path.insert(0,'/data_extraction')

# %%
import pandas as pd
df = pd.read_csv("data_extraction/books.csv")
df
# Out:
#                                                   Book  \
# 0    Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 1                            Adam Mickiewicz  Do D. D.
# 2                              Adam Mickiewicz  Zaloty
# 3    Mickiewicz Adam  Ballady i romanse Tukaj albo ...
# 4                     Adam Mickiewicz  Pieśń filaretów
# ..                                                 ...
# 149                          Adam Mickiewicz  Do D… D…
# 150  Adam Mickiewicz  Dziadów części III Ustęp Oles...
# 151    Adam Mickiewicz  Dziady. Poema Dziady, część IV
# 152  Adam Mickiewicz  Sonety odeskie Sonet II. Do L...
# 153         Adam Mickiewicz  Liryki lozańskie Widzenie
#
#                                                   Text
# 0    Adomas Mickevičius\n\nKrymo sonetai\nAjudagas\...
# 1    Adam Mickiewicz\n\nDo D. D.\n\n\n\nElegia\n\n ...
# 2    Adam Mickiewicz\n\nZaloty\n\n\n\nPóki córeczki...
# 3    Mickiewicz Adam\n\nBallady i romanse\nTukaj al...
# 4    Adam Mickiewicz\n\nPieśń filaretów\n\n\n\n  He...
# ..                                                 ...
# 149  Adam Mickiewicz\n\nDo D… D…\n\n\n\nMoja pieszc...
# 150  Adam Mickiewicz\n\nDziadów części III Ustęp\nO...
# 151  Adam Mickiewicz\n\nDziady. Poema\nDziady, częś...
# 152  Adam Mickiewicz\n\nSonety odeskie\nSonet II. D...
# 153  Adam Mickiewicz\n\nLiryki lozańskie\nWidzenie\...
#
# [154 rows x 2 columns]

# %% [markdown]
# For each book, we will split each verse and annotate it with the title, later on we will feed it to the model and ask to create a question and answer based on it

# %%
# Remove the first 5 lines from the text column, theyre the same as the book column
def remove_first_five_lines(text):
    return '\n'.join(text.split('\n')[5:])

# Apply the function to the 'Text' column
df['Text'] = df['Text'].apply(remove_first_five_lines)

df.head()
# Out:
#                                                 Book  \
# 0  Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 1                          Adam Mickiewicz  Do D. D.
# 2                            Adam Mickiewicz  Zaloty
# 3  Mickiewicz Adam  Ballady i romanse Tukaj albo ...
# 4                   Adam Mickiewicz  Pieśń filaretów
#
#                                                 Text
# 0  \n\n\nMėgstu ant Ajudago rymodams matyti,\nKai...
# 1  \nElegia\n\n  Gdybyś ty na dzień jeden była w ...
# 2  \nPóki córeczki opiewałem wdzięki:\nMamunia sł...
# 3  \n\n\n(we czterech częściach)\n\n\n\n\nI\n\n  ...
# 4  \n  Hej użyjmy żywota!\nWszak żyjem tylko raz:...

# %%
# Check the text
df.Text[0]
# Out:
# '\n\n\nMėgstu ant Ajudago rymodams matyti,\nKaip putojančios bangos verpetais puškuoja,\nBei sidabro vainikais juosia marių srytį,\nIr tarsi vaivorykštės aplinkui ratuoja,\n\nAtsimuša į seklių, sekliaus išblaškyti,\nLyg didžiažuvių būriai krantus atakuoja,\nPaveldėtų sausumą, tečiaus nuvaryti,\nVėl kiaukerus, koralus ir perlus tebšluoja.\n\nJaunasis dainiau! Lygiai ir tavo širdyje\nKensmas dažnai sujudin vėsulas grumzdingas,\nBet sveikamjam pakėlus bard’ną įkvėpimo,\n\nAnas be blėdies žūva gelmėj užmiršimo,\nIr už save palieka giesmes nemirtingas,\nTavo garbei vainiką nupint ateityje.\n\n\n\n\n'

# %% [markdown]
# Most of the poems the poems/books are in verses, by splitting each per verse we can perform some pretty efficient chunking without losing much of the context. Later on we will perform some extra cleaning.

# %%
exploded_df = pd.DataFrame(columns=df.columns)

verse_series_list = []

for row in df.iterrows():

  # Split the verse in each row
  split_text = row[1].Text.split("\n\n")

  for idx,verse in enumerate(split_text):
    verse = verse.replace("\n", "")


    if (not verse) | (len(verse)<10):
      continue

    verse = verse

    verse_series_list.append(pd.Series([row[1].Book, verse], index=df.columns))

print(len(verse_series_list))
# Out:
# 4924

# %%
exploded_df = pd.concat(verse_series_list, axis=1).T
exploded_df.head()
# Out:
#                                                 Book  \
# 0  Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 1  Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 2  Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 3  Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 4                          Adam Mickiewicz  Do D. D.
#
#                                                 Text
# 0  Mėgstu ant Ajudago rymodams matyti,Kaip putoja...
# 1  Atsimuša į seklių, sekliaus išblaškyti,Lyg did...
# 2  Jaunasis dainiau! Lygiai ir tavo širdyjeKensma...
# 3  Anas be blėdies žūva gelmėj užmiršimo,Ir už sa...
# 4    Gdybyś ty na dzień jeden była w mojej duszy…...

# %%
result = pd.DataFrame([[]])
result['result'] = exploded_df['Text'].apply(len).mean()
result
# Out:
#        result
# 0  246.628554

# %% [markdown]
# # Enriching the data
# We're going to load in a llama model to enrich the dataset and prepare it for finetuning

# %% [markdown]
# # Important!
#
# llama is a gated model, request it at https://huggingface.co/meta-llama/Llama-2-70b-chat-hf and add your api key

# %%
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/fifi/.cache/huggingface/token
# Login successful

# %%
# !pip install light-the-torch torchvision torchaudio sentencepiece accelerate bitsandbytes
# Out:
# Collecting light-the-torch
#   Downloading light_the_torch-0.7.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting torchvision
#   Downloading torchvision-0.16.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.3 MB/s eta 0:00:008.5 MB/s eta 0:00:01
# Collecting accelerate
#   Using cached accelerate-0.24.1-py3-none-any.whl.metadata (18 kB)
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.41.2.post2-py3-none-any.whl.metadata (9.8 kB)
# Collecting pip<23.3,>=22.3 (from light-the-torch)
#   Downloading pip-23.2.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Collecting torch==2.1.1 (from torchvision)
#   Using cached torch-2.1.1-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting filelock (from torch==2.1.1->torchvision)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from torch==2.1.1->torchvision)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch==2.1.1->torchvision)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch==2.1.1->torchvision)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch==2.1.1->torchvision)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting fsspec (from torch==2.1.1->torchvision)
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in ./.venv/lib/python3.11/site-packages (from accelerate) (5.9.6)
# Collecting pyyaml (from accelerate)
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting huggingface-hub (from accelerate)
#   Using cached huggingface_hub-0.19.4-py3-none-any.whl.metadata (14 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub->accelerate)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests->torchvision) (2023.11.17)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.1.1->torchvision)
#   Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting mpmath>=0.19 (from sympy->torch==2.1.1->torchvision)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading light_the_torch-0.7.5-py3-none-any.whl (14 kB)
# Downloading torchvision-0.16.1-cp311-cp311-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.3 MB/s eta 0:00:006.2 MB/s eta 0:00:01
# Using cached torch-2.1.1-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
# Downloading torchaudio-2.1.1-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.0 MB/s eta 0:00:0031m10.7 MB/s eta 0:00:01
# Using cached accelerate-0.24.1-py3-none-any.whl (261 kB)
# Using cached bitsandbytes-0.41.2.post2-py3-none-any.whl (92.6 MB)
# Using cached Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
# Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Installing collected packages: sentencepiece, mpmath, bitsandbytes, typing-extensions, tqdm, sympy, pyyaml, pip, pillow, networkx, MarkupSafe, fsspec, filelock, light-the-torch, jinja2, huggingface-hub, torch, torchvision, torchaudio, accelerate
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed MarkupSafe-2.1.3 accelerate-0.24.1 bitsandbytes-0.41.2.post2 filelock-3.13.1 fsspec-2023.10.0 huggingface-hub-0.19.4 jinja2-3.1.2 light-the-torch-0.7.5 mpmath-1.3.0 networkx-3.2.1 pillow-10.1.0 pip-23.2.1 pyyaml-6.0.1 sentencepiece-0.1.99 sympy-1.12 torch-2.1.1 torchaudio-2.1.1 torchvision-0.16.1 tqdm-4.66.1 typing-extensions-4.8.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForCausalLM

# model_name = "HuggingFaceH4/zephyr-7b-beta"
# model = AutoModelForCausalLM.from_pretrained(
#     model_name, load_in_4bit=True
# )
# tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, add_bos_token=False)

# %%
# import transformers

# pipe = transformers.pipeline(
#     "text-generation",
#     model=model,
#     tokenizer=tokenizer,
# )

# %%
# sequences = pipe(
#    "Who is adam mickiewicz?",
#     max_length=400,
#     do_sample=True,
#     top_k=10,
#     num_return_sequences=1,
#     eos_token_id=tokenizer.eos_token_id,
# )
# for seq in sequences:
#     print(f"Result: {seq['generated_text']}")

# %% [markdown]
# After trying Llama 70b (couldn't get it to load properly) and zephyr-7b (not enough polish), let's try gpt-3 for this:

# %%
exploded_df
# Out:
#                                                    Book  \
# 0     Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 1     Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 2     Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 3     Adomas Mickevičius  Krymo sonetai Ajudagas tłu...
# 4                             Adam Mickiewicz  Do D. D.
# ...                                                 ...
# 4919  Adam Mickiewicz  Sonety odeskie Sonet II. Do L...
# 4920  Adam Mickiewicz  Sonety odeskie Sonet II. Do L...
# 4921         Adam Mickiewicz  Liryki lozańskie Widzenie
# 4922         Adam Mickiewicz  Liryki lozańskie Widzenie
# 4923         Adam Mickiewicz  Liryki lozańskie Widzenie
#
#                                                    Text
# 0     Mėgstu ant Ajudago rymodams matyti,Kaip putoja...
# 1     Atsimuša į seklių, sekliaus išblaškyti,Lyg did...
# 2     Jaunasis dainiau! Lygiai ir tavo širdyjeKensma...
# 3     Anas be blėdies žūva gelmėj užmiršimo,Ir už sa...
# 4       Gdybyś ty na dzień jeden była w mojej duszy…...
# ...                                                 ...
# 4919  O luba! niech twe oczy przyznać się nie boją;J...
# 4920  Że uciekać i kochać bez nadziei muszę.Niech śl...
# 4921      Dźwięk mię uderzył… Nagle moje ciało,Jak ó...
# 4922      Przeszedłem ludzkie ciała, jak przebiegaPr...
# 4923      Stały otworem ludzkich serc podwoje,Patrzy...
#
# [4924 rows x 2 columns]

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/ce/3f/1dafc52526337d1c554227b0e6f16a1aee18e63bf5cd03fd7774297059b2/langchain-0.0.338-py3-none-any.whl.metadata
#   Downloading langchain-0.0.338-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.11/site-packages (from langchain) (6.0.1)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/c7/55/d1d2ad054fb7e9188681d56df40ed81c2c198314a805b180b0ec99019da1/SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.3 from https://files.pythonhosted.org/packages/c0/c3/3491f4a4b54798415f9a3bf69f2be2f2edaf2aaa5d2b0171b4420feaf45b/aiohttp-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading aiohttp-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting anyio<4.0 (from langchain)
#   Obtaining dependency information for anyio<4.0 from https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl.metadata
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/8d/e2/528c52001a743a7faa28e6d3095d9f01b472d3efee62d62101403bf1a70a/dataclasses_json-0.6.2-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.1.0,>=0.0.63 (from langchain)
#   Obtaining dependency information for langsmith<0.1.0,>=0.0.63 from https://files.pythonhosted.org/packages/a0/d4/79038c47526f84ad9b6ec2a27b46e8e97897e70cd0579c9a6dbcf1d2adea/langsmith-0.0.65-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.65-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2,>=1 in ./.venv/lib/python3.11/site-packages (from langchain) (1.26.2)
# Collecting pydantic<3,>=1 (from langchain)
#   Obtaining dependency information for pydantic<3,>=1 from https://files.pythonhosted.org/packages/e2/2c/9906b7abc337b0250a5634de5396e2f3cb1b837af0616424c2225a65aa80/pydantic-2.5.1-py3-none-any.whl.metadata
#   Downloading pydantic-2.5.1-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.11/site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Obtaining dependency information for tenacity<9.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.0.4-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.9.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/9d/8b/8ab8143541b2c5fff4189fad7853e61d30e4ec4749ebf91e1d598c4e7c57/frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.11/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.11/site-packages (from anyio<4.0->langchain) (1.3.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl.metadata
#   Using cached marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.3 (from pydantic<3,>=1->langchain)
#   Obtaining dependency information for pydantic-core==2.14.3 from https://files.pythonhosted.org/packages/23/b4/bedc009e34e181927cb47ec3f62e36e9bedd4de52d5a8737dece87998b85/pydantic_core-2.14.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pydantic_core-2.14.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading langchain-0.0.338-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.1 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Downloading aiohttp-3.9.0-cp311-cp311-macosx_11_0_arm64.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 8.5 MB/s eta 0:00:008 MB/s eta 0:00:01
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.0.65-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.5 MB/s eta 0:00:00
# Downloading pydantic-2.5.1-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.6/381.6 kB 7.6 MB/s eta 0:00:000m eta 0:00:01
# Downloading pydantic_core-2.14.3-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.4 MB/s eta 0:00:0031m12.4 MB/s eta 0:00:01
# Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl (46 kB)
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: tenacity, SQLAlchemy, pydantic-core, mypy-extensions, multidict, marshmallow, jsonpointer, frozenlist, anyio, annotated-types, yarl, typing-inspect, pydantic, jsonpatch, aiosignal, langsmith, dataclasses-json, aiohttp, langchain
# Successfully installed SQLAlchemy-2.0.23 aiohttp-3.9.0 aiosignal-1.3.1 annotated-types-0.6.0 anyio-3.7.1 dataclasses-json-0.6.2 frozenlist-1.4.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.338 langsmith-0.0.65 marshmallow-3.20.1 multidict-6.0.4 mypy-extensions-1.0.0 pydantic-2.5.1 pydantic-core-2.14.3 tenacity-8.2.3 typing-inspect-0.9.0 yarl-1.9.2
# WARNING: There was an error checking the latest version of pip.

# %%
# Create a model

from langchain.pydantic_v1 import BaseModel, Field


class Conversation(BaseModel):
    """Identifying information about a person."""

    question: str = Field(..., description="Zadaj pytanie Adamowi Mickiewiczowi")
    answer: str = Field(..., description="Odpowiedź Adama Mickiewicza, zawsze pisana wierszem i po polsku, minimum 50 słów")

# %%
from langchain.chains.openai_functions import (
    create_openai_fn_chain,
    create_openai_fn_runnable,
    create_structured_output_chain,
    create_structured_output_runnable,
)
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate



llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.7, openai_api_key="API KEY")
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Nazywasz się Adam Mickiewicz, jesteś polskim poetą i mówisz wierszem. Przetłumacz wszystkie utwory na polski.",
        ),
        (
            "human",
            "Zbuduj pytanie (skierowane do adama mickiewicza, w formie krotkiego generalnego pytania) i odpowiedź, MUSZA BYC PO POLSKU i musi mieć max 50 słów: {input}",
        ),
        ("human", "ZAWSZE ODPOWIADAJ WIERSZEM I MAKSYMALNIE 50 SŁÓW,PYTANIE I ODPOWIEDŹ MUSZĄ BYĆ PO POLSKU! ODPOWIEDŹ TO MUSI BYĆ WIERSZ W STYLU ADAMA MICKIEWICZA (NA PODSTAWIE TEKSTU POWYŻEJ). Użyj poprawnego formatu!!!!"),
    ]
)

# %%
import pandas as pd
import threading
from queue import Queue
from langchain.chains.openai_functions import create_structured_output_runnable
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# Assuming llm and prompt are already initialized as before

def generate_conversation_threaded(row_index, row, output_queue, stop_event, csv_file):
    """
    Generate a conversation using threading and save the result to a CSV file.
    """
    try:
        if stop_event.is_set():
            raise TimeoutError("Thread execution timed out")

        runnable = create_structured_output_runnable(Conversation, llm, prompt)
        conversation = runnable.invoke({"input": row[1]})
        result = pd.Series([conversation.question, conversation.answer], index=['Question', 'Answer'])
        output_queue.put(result)

        # Save result to CSV
        with open(csv_file, 'a') as f:
            result.to_frame().T.to_csv(f, header=f.tell()==0, index_label='Index')
    except Exception as e:
        print(f"Error occurred: {e}")
        output_queue.put(pd.Series([None, None], index=['Question', 'Answer']))

def process_dataframe(df, csv_file, timeout=60):
    """
    Process each row of the DataFrame using threading with a timeout and save to CSV.
    """
    output_queue = Queue()
    threads = []
    stop_events = []

    for index, row in df.iterrows():
        stop_event = threading.Event()
        thread = threading.Thread(target=generate_conversation_threaded, args=(index, row, output_queue, stop_event, csv_file))
        threads.append(thread)
        stop_events.append(stop_event)
        thread.start()

        # Set a timer to stop the thread after a timeout
        timer = threading.Timer(timeout, stop_event.set)
        timer.start()

    for thread in threads:
        thread.join()

    results = [output_queue.get() for _ in range(len(df))]
    return pd.concat(results, axis=1)

# File to save the results
csv_file = "conversation_results.csv"

# %%
updated_df = process_dataframe(exploded_df, csv_file)
# Out:
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# /var/folders/h1/fhrkxmnn5_q504_ffmhxrl0r0000gn/T/ipykernel_19757/1043381969.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conversation = runnable.invoke({"input": row[1]})
# ...
# __root__
#   Expecting property name enclosed in double quotes: line 5 column 3 (char 521) (type=value_error.jsondecode; msg=Expecting property name enclosed in double quotes; doc={
#   "output": {
#     "question": "Dlaczego Protazy dobrze zrobił?",
#     "answer": "Protazy w drogę pośpieszył,\nBo by pozwem się nacieszył,\nW Soplicowie zmieniano plany,\nRobak do Sędziego zadumany\nMówił o pani Telimenie,\nJak Zosię chce wabić, uwieść,\nObmyślmy środki, jak się pozbyć\nI układy Sędziemu zerwać.\nRobak mówił o Jaceku, Hrabi,\nO plotkach, zwadach, układach,\nSędzia krzyczał, tupał nogami,\nNie ma zgody, nie ma zgody!\nKsiądz mówił o wojnie, o Polsce,\nO armii Napoleona,\nO wskrzeszeniu Ojczyzny.",
#   }
# }; pos=521; lineno=5; colno=3)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 49 (char 132) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czy Jan Trzeci przyjdzie z gwiazdą na zachodzie?",
#     "answer": "Sędzia rzekł: „Niech będzie amen!
# Oby gwiazda zwiastowała Jan Trzeci!
# Bohater z zachodu, wielki i sławny,
# Przybyć może, kometa wraz z nim, niech daj Boże!”"
#   }
# }; pos=132; lineno=4; colno=49)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 62 (char 257) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Jaki był przypadek ciekawy, podobny do zdarzenia wczorajszej wyprawy, co trafił się najpierwszym strzelcom za mych czasów, posłowi Rejtanowi i Księciu Denassów?",
#     "answer": "Przypadek taki był, że Rejtan oraz Denassów,\\
#     W strzelbę oddali razem, jak jedno ciało,\\
#     Lecz kula Rejtana, nieznana dla wielu,\\
#     Nie trafiła w cel, lecz w serce posłowi,\\
#     A Denassów kula, jak błyskawica w mroku,\\
#     Zabiła nieprzyjaciela, oddając strzał wprost w czoło."
#   }
# }; pos=257; lineno=4; colno=62)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Expecting ',' delimiter: line 4 column 437 (char 514) (type=value_error.jsondecode; msg=Expecting ',' delimiter; doc={
#   "output": {
#     "question": "Czy ty oszalał, Ryków? To służba cesarska?",
#     "answer": "Major w gniewie wstał, parskał od złości,\nSłużby nie drużby, to czysta logika,\nBuntowników nie puszczać, to jego postanowienie,\nPolacy, nie myślcie o buncie!\nSzlachta łajdaki, Dobrzyńscy, znam ich dobrze,\nNiech ich łajdactwo moczy w kazamatach!\nMajor znów śmieje się, patrząc w okno,\nDobrzyński, ten sam, co w surducie siedził,\nNa reducie kłótnię rozpoczął,\nOn, nie ja, zaczął, gdy tańczyłem mazura,\nKrzyknął: "Precz za drzwi złodzieja!"\nByłem pod śledztwem za pułkowej kasy kradzież,\nAmbarasy mnie spotkały, a co do niego?\nJa koza, on woźnica, ale będzie łoza!"
#   }
# }; pos=514; lineno=4; colno=437)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 48 (char 221) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Jakie szczęście spotkało Sopliców, gdy Hrabia z lepszymi końmi i posłusznym dżokejem, biegł przed szlachtą, która była skora do wieszania?",
#     "answer": "Soplicom szczęście zgotował los,
# Hrabia z koniami, jak skrzydlaty kos,
# Przed szlachtą biegł, o milę wyprzedził ich,
# A dżokej wierny, niczym wojsko zwycięskich.
# Burząca szlachta, zwyczaje wieszająca,
# Zazdrościła temu szczęściu biegłąca."
#   }
# }; pos=221; lineno=4; colno=48)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 420 (char 493) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Co Hrabia zrobił, gdy Telimena upadła?",
#     "answer": "Hrabia padł na kolana, by ją ratować,\nPrzejęty sceną, nieco zaskoczony.\nTelimenie rzekł: „Panno, Zofio, Telimeno!\nNie splamię tej szpady krwią bezbronnych ludzi.\nSoplicowie, jesteście moimi więźniami.\nTak czyniłem we Włoszech, pod opoką\nZdobytą tabor zbójców mordowałem,\nRozbrojonych zabrałem i związanych prowadziłem;\nIdąc za końmi, triumf zdobyłem wspaniały,\nPotem ich powiesiłem u stóp Etny.”
#   }
# }; pos=493; lineno=4; colno=420)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 57 (char 133) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czy Kapitan złoży broń przed Podkomorzym?",
#     "answer": "«Nie splamię czci mojej, nie złożę broni,
# Bije się, choć sam zostałem w tej koronie,
# Choć krzyczę, że nigdy nie dam się pojmać,
# W walce zawsze będę do końca walczyć stać!»"
#   }
# }; pos=133; lineno=4; colno=57)
# Error occurred: 1 validation error for _OutputFormatter
# output -> answer
#   field required (type=value_error.missing)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 59 (char 161) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czym było to lekarstwo, które Bóg objawił, aby naprawić i poprawić?",
#     "answer": "To lekarstwo jedyne, co Bóg raczył objawić,
# By poprawić i naprawić, czego było potrzeba.
# To było lekarstwo pełne możliwości i mocy,
# Które miało uzdrowić i ożywić nasze życie."
#   }
# }; pos=161; lineno=4; colno=59)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Expecting ',' delimiter: line 4 column 310 (char 480) (type=value_error.jsondecode; msg=Expecting ',' delimiter; doc={
#   "output": {
#     "question": "Czy Bóg przebacza grzesznikom? Klucznik, w swym opowiadaniu, tchnie nadzieję w serca. Czyż zapomnienie zbrodni nie jest darem od Nieba?",
#     "answer": "«Nadzieję w twym sercu tchnie mój opis, Czy Bóg przebacza grzesznikom, czy to zmyśl? Klucznik, przerywając, mówił o zadośćuczynieniu. Choć zemsta w jego sercu buzowała, Ostatecznie Bóg sprawiedliwości udzielał, Odpuszczając zbrodniarzom, którzy pokutowali, Tym gestem zbawienia dusze podnosił.""
#   }
# }; pos=480; lineno=4; colno=310)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 63 (char 167) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Co zaszło, gdy szlachcic wykrzyknął 'Veto' i do kłótni pchnął innych?",
#     "answer": "Przy drzwiach tłoczy się tłum, gotowy do bójki,
# Szlachcic szablą błysnął, krwawą rzeź zapoczątkował.
# Wszyscy na zgodę nie zważają, w kuchni refektarza
# Szaleją napięci, a rozum w głowach zaginął."
#   }
# }; pos=167; lineno=4; colno=63)
# Error occurred: 1 validation error for _OutputFormatter
# output -> answer
#   field required (type=value_error.missing)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 53 (char 253) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czy kiedy nadejdzie dzień zemsty i chwały, gdy wojna naszych orłów przyniesie zwycięstwo? Czy wtedy nasi wojownicy złożą broń i będą słuchać opowieści o przeszłości?",
#     "answer": "Kiedy nadejdzie czas zemsty i chwały,
# Gdy orły nasze przyniosą zwycięstwo,
# Wtedy wojownicy złożą broń,
# By usłyszeć opowieści o przeszłości.
# Zapłaczą nad losami ojców,
# Ale łza ta nie splami ich twarzy."
#   }
# }; pos=253; lineno=4; colno=53)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid \escape: line 4 column 57 (char 126) (type=value_error.jsondecode; msg=Invalid \escape; doc={
#   "output": {
#     "question": "Co takiego zdarzyło się w wierszu?",
#     "answer": "Rębajło fechtując, klęczał już w cieniu, \
#     Jenerała objął i łzami się skłonił. \
#     Pytał o szermierców z pałacu królewskiego, \
#     O szablistów sławnych i cios mopanku. \
#     Jenerał go pocieszał, mówiąc o dziedzicu, \
#     O skarbionym scyzoryku, co go kochał. \
#     Scyzoryk teraz oddaje w ręce jenerała, \
#     Niechaj służy mu, jak służył w minionych latach. \
#     Rębajło spokojny, bo wie, że będzie czuwał, \
#     Nad swoim drogocennym dziełem pochowanym. \
#     Jenerał przyjmuje w darze, szablę mu ofiaruje, \
#     Niemieckie szpadki porzuca, szlachecki kijek nosi. \
#     Scyzoryk zostaje w rodzinie, w rękach jenerała, \
#     Wspomnienie Rębajłowa, co go kochał jak żonę. \
#     Wiersz ten opowiada o więziach i miłości, \
#     O związku dwóch dusz, przez szermierców splecionych. \
#     Niech żyje Rębajło, w sercach naszych trwa, \
#     Jego cios mopanku, niezawodny jak zawsze."
#   }
# }; pos=126; lineno=4; colno=57)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 49 (char 158) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "O Matko Polsko! Ty tak świeżo w grobieZłożona… Nie masz sił mówić o tobie!",
#     "answer": "W grobie leżę, Matko Polsko miła,
# Nie mogę mówić, sił już nie mam w sobie.
# Lecz serce me wciąż bije dla ciebie,
# Bo Polsko moja, tyś wieczna jak gwiazda na niebie."
#   }
# }; pos=158; lineno=4; colno=49)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 44 (char 114) (type=value_error.jsondecode; msg=Invalid control character at; doc={
# "output": {
# "question": "Jaki był charakter kaprala Dobrzyńskiego?",
# "answer": "Kapral Dobrzyński, zły i ponury,
# Dla Zosi swoje serce stracił.
# Kwiaty dla niej nosił, koszyczki pleść,
# Gniazda ptasie wybierał, zauszniczki robił.
# Lecz mimo tego, niewdzięczna była Zosia,
# Uciekała przed nim, ojciec bronił ich miłości.
# On siadał na parkanie, przez okno ją oglądał,
# W konopie się wkradał, by widzieć jej ogródki.
# Ale ona była niewdzięczna, nie doceniła jego darów,
# I na koniec skończył tańcząc mazurka.
# Potem nacisnął kaszkiet na uszy
# I poszedł w obóz, gdzie stała warta przy armatach.
# Tam grał w drużbarta, osładzając żałość kieliszkiem.
# Taka była dla Zosi Dobrzyńskiego stałość."
# }
# }; pos=114; lineno=4; colno=44)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 51 (char 207) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Jak długo dręczysz się w czyścowej zagubie za taką srogość, póki ktoś z tamtego świata nie powie na ciebie choć: *lubię*?",
#     "answer": "Czyścowa zaguba dręczy mnie latami,
# Srogość za srogość, nie ma ukojenia.
# Choć mąż z tamtego świata powie choćby: *lubię*,
# To wciąż jestem w purgatorium więzione."
#   }
# }; pos=207; lineno=4; colno=51)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 50 (char 222) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Co się stanie, gdy spadnie wyroków zasłona i przyszłość z pod ciemnych wskaże chmur? Kto poznaje Marylę, lecz na nieszczęście zapiał kur?",
#     "answer": "Gdy zasłona wyroków spadnie w dół,
# A przyszłość w mroku wskaże swój kształt zuchwały.
# To wtedy Maryła zostanie poznana,
# Lecz nieszczęście przerywa kurzy głos niegrzeczny."
#   }
# }; pos=222; lineno=4; colno=50)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Expecting property name enclosed in double quotes: line 5 column 3 (char 211) (type=value_error.jsondecode; msg=Expecting property name enclosed in double quotes; doc={
#   "output": {
#     "question": "Kim jest ten człowiek? Coś jak upiór.",
#     "answer": "Lodowata pierś, oczy otworem, usta zmarzłe, nie dla świata. Upiorem go nazwać trzeba, nie wykluczone, przecież jestem.",
#   }
# }; pos=211; lineno=5; colno=3)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 44 (char 157) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Książę Koriat zasmucił się niepomału, jaką przemianę w swojej córce upatrując?",
#     "answer": "Krótko potem wrócił z wojny,
# Książę Koriat zasmucił się niepomału.
# W kochanej córce swojej upatrując przemianę,
# Łzy, wzdychania, bladość, lęk przed ojcem, drżenia.
# „Córko odrodna — zawołał — wiodła cię rozpusta,
# Zhańbiłaś na wieki dom ojcowski,
# Idź precz sprzed oblicza mego,
# Śmiercią okrutną pomrzecie”.
# Wytrąbiono z urzędu po mieście,
# Kto by wymienił gamrata księżniczki Żywili,
# O nim lice jakowe powziął,
# Bogato udarowan odejdzie.
# Trąbienie na świat poszło,
# Skryte miłości nikt nie wiedział,
# Koriatowi doniósł.
# Księżniczka Żywila w szczególnym zamiłowaniu,
# Na rycerza Poraja, który płakał,
# Na dworze w wesołą twarz ubrać się umiał,
# Żadne podejrzenie nie przyszło jako żywo."
#   }
# }; pos=157; lineno=4; colno=44)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Expecting ',' delimiter: line 4 column 1 (char 135) (type=value_error.jsondecode; msg=Expecting ',' delimiter; doc={
# "output": {
# "question": "Duchu przeklęty, dlaczego ożywiasz ogień w nieczułej ziemi? Czyżbyś znów przyświecał mi, przeklęty blasku?"
# "answer": "Ogień życia wzbudzić muszę w nieczułej ziemi, duchu przeklęty. Przyświecasz mi znów, przeklęty blasku zgasły i znów rozpalony."
# }
# }; pos=135; lineno=4; colno=1)
# Error occurred: 1 validation error for _OutputFormatter
# output -> answer
#   field required (type=value_error.missing)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 52 (char 216) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czy wzrok twój, przyzwyczajony do światła i słońca, nie lęka się nawet śmierci? Czy potrafisz cierpliwie wysłuchać mowy grobowej?",
#     "answer": "Wzrok mój, przyzwyczajony do słońca,
# Nie lęka się nawet śmierci grozy,
# Cierpliwie wysłuchuje mowy grobowej,
# Do końca, bez żadnych wyrzutów."
#   }
# }; pos=216; lineno=4; colno=52)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 62 (char 151) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Co czuł Strzelec, zadrżałszy i uśmiechając się gorzko?",
#     "answer": "Wzburzenie w sercu czuł, strach go ogarniał,\\
#     Dłonie drżały, broń wstawił z gniewem i z goryczą.\\
#     "
#   }
# }; pos=151; lineno=4; colno=62)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 50 (char 125) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "O morze! Jakie sekrety skrywasz na dnie?",
#     "answer": "W twoich falach wesoło żyje polip,
# Gdy niebo się chmurami mrozi,
# Rozwija długie ramiona na ciszę."
#   }
# }; pos=125; lineno=4; colno=50)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 55 (char 179) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Czy Jenerał PodolskichZiem, zwiedzając Polskę, częściej zaglądał do książek niż do lasów?",
#     "answer": "Książę jenerał, w podróży przez ziemie,
# Często do książek, nie lasów, zaglądał wiele.
# Gustów cudzoziemskich był oddany pan,
# Do alkówek damskich i teatru szan.
# Choć do myślistwa niechętny był nieco,
# W książkach i zabawach znajdował swe szczęście."
#   }
# }; pos=179; lineno=4; colno=55)
# Error occurred: 1 validation error for _OutputFormatter
# __root__
#   Invalid control character at: line 4 column 60 (char 166) (type=value_error.jsondecode; msg=Invalid control character at; doc={
#   "output": {
#     "question": "Adamie Mickiewiczu, jak Major zdecydował, kto będzie walczył z Rykołem?",
#     "answer": "Ryków do Majora rzekł: 'Wyjdź na pojedynek,'
#     'I pomścij się za jego raniejszy uczynek.'
#     Major nie mógł odstąpić, żołnierzy bronić,
#     Bo do niego batalionu komenda należy.
#     A więc Ryków, zuch na szpady, wyjdź ty,
#     Lub wyjdź z poruczników jeden z naszych.'
#     Tak zdecydowali, na szpady się zgodzili,
#     Tadeusz z Hrabią, broń nie mając, walczyć mieli."
#   }
# }; pos=166; lineno=4; colno=60)
